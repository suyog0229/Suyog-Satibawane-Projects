# 11905600.0
# 41518800.0
# 32222500.0
# 18931800.0
# 25233200.0
# 29850100.0
# 15273000.0
# 15151600.0
# 30930100.0
# 25442200.0
# 18601700.0
# 8748030.0
# 22946500.0
# 15375600.0
# 9194440.0
# 11763000.0
# 12364100.0
# ...

# %%
# def convert_volume(volume):
#     if 'K' in volume:
#         return float(volume.replace('K', '')) * 1000
#     elif 'M' in volume:
#         return float(volume.replace('M', '')) * 1000000
#     return float(volume)

# %%
#df['Volume'] = df['Volume'].apply(convert_volume)

# %%
df.head()
# Out:
#          Date        Open        High         Low   Adj Close      Volume  \
# 0  17-09-2014  465.864014  468.174011  452.421997  457.334015  21056800.0
# 1  18-09-2014  456.859985  456.859985  413.104004  424.440002  34483200.0
# 2  19-09-2014  424.102997  427.834991  384.532013  394.795990  37919700.0
# 3  20-09-2014  394.673004  423.295990  389.882996  408.903992  36863600.0
# 4  21-09-2014  408.084991  412.425995  393.181000  398.821014  26580100.0
#
#    capmrktcurusd  asseteodcompletiontime    PriceUSD       Close
# 0   6.060691e+09              1614336399  267.797617  457.334015
# 1   5.671343e+09              1614336400  259.613696  424.440002
# 2   5.234787e+09              1614336400  236.380819  394.795990
# 3   5.464482e+09              1614336401  217.193473  408.903992
# 4   5.324716e+09              1614336402  234.392998  398.821014

# %%
# df['Date']= pd.to_datetime(df['Date'])

# %%
# df['Year'] = df['Date'].dt.year

# %%
# df['Month'] = df['Date'].dt.month

# %%
# df['Day'] = df['Date'].dt.day

# %%
df.head()
# Out:
#          Date        Open        High         Low   Adj Close      Volume  \
# 0  17-09-2014  465.864014  468.174011  452.421997  457.334015  21056800.0
# 1  18-09-2014  456.859985  456.859985  413.104004  424.440002  34483200.0
# 2  19-09-2014  424.102997  427.834991  384.532013  394.795990  37919700.0
# 3  20-09-2014  394.673004  423.295990  389.882996  408.903992  36863600.0
# 4  21-09-2014  408.084991  412.425995  393.181000  398.821014  26580100.0
#
#    capmrktcurusd  asseteodcompletiontime    PriceUSD       Close
# 0   6.060691e+09              1614336399  267.797617  457.334015
# 1   5.671343e+09              1614336400  259.613696  424.440002
# 2   5.234787e+09              1614336400  236.380819  394.795990
# 3   5.464482e+09              1614336401  217.193473  408.903992
# 4   5.324716e+09              1614336402  234.392998  398.821014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2992 entries, 0 to 2991
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    2992 non-null   object
#  1   Open                    2992 non-null   float64
#  2   High                    2992 non-null   float64
#  3   Low                     2992 non-null   float64
#  4   Adj Close               2992 non-null   float64
#  5   Volume                  2992 non-null   float64
#  6   capmrktcurusd           2991 non-null   float64
#  7   asseteodcompletiontime  2992 non-null   int64
#  8   PriceUSD                2992 non-null   float64
#  9   Close                   2992 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 233.9+ KB

# %%
df.shape
# Out:
# (2992, 10)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Open                      0
# High                      0
# Low                       0
# Adj Close                 0
# Volume                    0
# capmrktcurusd             1
# asseteodcompletiontime    0
# PriceUSD                  0
# Close                     0
# dtype: int64

# %%
df['capmrktcurusd'].fillna(df['capmrktcurusd'].median(),inplace=True)
# Out:
# C:\Users\Jayesh Bhamare\AppData\Local\Temp\ipykernel_15152\926080604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['capmrktcurusd'].fillna(df['capmrktcurusd'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Open                      0
# High                      0
# Low                       0
# Adj Close                 0
# Volume                    0
# capmrktcurusd             0
# asseteodcompletiontime    0
# PriceUSD                  0
# Close                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
num_col = df[['Open','High','Low','Volume']]

# %%
df_new = df.drop('Date',axis=1,inplace=True)

# %%
df.describe()
# Out:
#                Open          High           Low     Adj Close        Volume  \
# count   2992.000000   2992.000000   2992.000000   2992.000000  2.992000e+03
# mean   12809.825801  13136.019769  12444.347681  12813.669324  1.631934e+10
# std    16281.327818  16698.721754  15797.944877  16276.339671  2.008489e+10
# min      176.897003    211.731003    171.509995    178.102997  5.914570e+06
# 25%      665.151519    677.853241    654.403259    665.255005  9.836927e+07
# 50%     6943.347657   7156.554932   6770.804932   6953.534912  7.035826e+09
# 75%    16407.499512  16842.327637  15843.749273  16488.660158  2.815139e+10
# max    67549.734380  68789.625000  66382.062500  67566.828130  3.510000e+11
#
#        capmrktcurusd  asseteodcompletiontime      PriceUSD         Close
# count   2.992000e+03            2.992000e+03   2992.000000   2992.000000
# mean    2.365959e+11            1.620219e+09  10635.235122  12813.669324
# ...

# %%
df.head()
# Out:
#          Open        High         Low   Adj Close      Volume  capmrktcurusd  \
# 0  465.864014  468.174011  452.421997  457.334015  21056800.0   6.060691e+09
# 1  456.859985  456.859985  413.104004  424.440002  34483200.0   5.671343e+09
# 2  424.102997  427.834991  384.532013  394.795990  37919700.0   5.234787e+09
# 3  394.673004  423.295990  389.882996  408.903992  36863600.0   5.464482e+09
# 4  408.084991  412.425995  393.181000  398.821014  26580100.0   5.324716e+09
#
#    asseteodcompletiontime    PriceUSD       Close
# 0              1614336399  267.797617  457.334015
# 1              1614336400  259.613696  424.440002
# 2              1614336400  236.380819  394.795990
# 3              1614336401  217.193473  408.903992
# 4              1614336402  234.392998  398.821014

# %%
for col in num_col:
    sns.boxplot(x = df[col])
    plt.show()

# %%
Q1 = df['High'].quantile(0.25)
Q3 = df['High'].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound, upper_bound)
# Out:
# -23568.858353749998 41089.03923225

# %%
def outliers(value):
    if value < lower_bound:
        return lower_bound
    
    elif value > upper_bound:
        return upper_bound
    
    else:
        return value

# %%
df['High'] = df['High'].apply(outliers)

# %%
Q1 = df['Low'].quantile(0.25)
Q3 = df['Low'].quantile(0.75)
IQR = Q3-Q1

# %%
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# %%
def outliers(value):
    if value < lower_bound:
        return lower_bound
    
    elif value > upper_bound:
        return upper_bound
    
    else:
        return value

# %%
df['Low'] = df['Low'].apply(outliers)

# %%
Q1 = df['Open'].quantile(0.25)
Q3 = df['Open'].quantile(0.75)
IQR = Q3-Q1

# %%
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# %%
def outliers(value):
    if value < lower_bound:
        return lower_bound
    
    elif value > upper_bound:
        return upper_bound
    
    else:
        return value

# %%
df['Open'] = df['Open'].apply(outliers)

# %%
# Q1 = df['Price'].quantile(0.25)
# Q3 = df['Price'].quantile(0.75)
# IQR = Q3-Q1

# %%
# lower_bound = Q1 - 1.5*IQR
# upper_bound = Q3 + 1.5*IQR

# %%
# def outliers(value):
#     if value < lower_bound:
#         return lower_bound
    
#     elif value > upper_bound:
#         return upper_bound
    
#     else:
#         return value

# %%
#df['Price'] = df['Price'].apply(outliers)

# %%
Q1 = df['Volume'].quantile(0.25)
Q3 = df['Volume'].quantile(0.75)
IQR = Q3-Q1

# %%
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# %%
def outliers(value):
    if value < lower_bound:
        return lower_bound
    
    elif value > upper_bound:
        return upper_bound
    
    else:
        return value

# %%
df['Volume'] = df['Volume'].apply(outliers)

# %%
for col in num_col:
    sns.boxplot(x = df[col])
    plt.show()

# %%
df.head()
# Out:
#          Open        High         Low   Adj Close      Volume  capmrktcurusd  \
# 0  465.864014  468.174011  452.421997  457.334015  21056800.0   6.060691e+09
# 1  456.859985  456.859985  413.104004  424.440002  34483200.0   5.671343e+09
# 2  424.102997  427.834991  384.532013  394.795990  37919700.0   5.234787e+09
# 3  394.673004  423.295990  389.882996  408.903992  36863600.0   5.464482e+09
# 4  408.084991  412.425995  393.181000  398.821014  26580100.0   5.324716e+09
#
#    asseteodcompletiontime    PriceUSD       Close
# 0              1614336399  267.797617  457.334015
# 1              1614336400  259.613696  424.440002
# 2              1614336400  236.380819  394.795990
# 3              1614336401  217.193473  408.903992
# 4              1614336402  234.392998  398.821014

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
X = df.drop('PriceUSD', axis =1)
Y = df['PriceUSD']

# %%
for col in X:
    print(col,":",df[col].skew())
# Out:
# Open : 1.1980198914233051
# High : 1.2000563209661537
# Low : 1.1907104363093524
# Adj Close : 1.5429273218823827
# Volume : 1.0889301516178906
# capmrktcurusd : 1.5520831045952155
# asseteodcompletiontime : 2.2621597542950056
# Close : 1.5429273218823827

# %%
for col in X:
    if df[col].skew()>0.5:
        df[col]=np.sqrt(df[col])
    print(col,":",df[col].skew())
# Out:
# Open : 0.5520103403161711
# High : 0.5545044941850422
# Low : 0.5439429466827219
# Adj Close : 0.7532315689965198
# Volume : 0.290149718603742
# capmrktcurusd : 0.7731440260746585
# asseteodcompletiontime : 2.2577219220143405
# Close : 0.7532315689965198

# %%
for col in X:
    sns.distplot(df[col])
    plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.9604791003327401

# %%
model.score(x_test,y_test)
# Out:
# 0.9604427241877495

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
print("Mean Squared Error: ",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error:  11279643.36113304

# %%
print("R2_Score: ",r2_score(y_test,y_pred))
# Out:
# R2_Score:  0.9604427241877495

# %%
import pickle

# %%
with open ("Bitcoin_Price.pkl","wb") as file:
    pickle.dump(model,file)

# %%
L = [[408.084991, 412.425995, 393.181, 398.821014, 26580100	,5324715501, 1614336402, 398.821014]]
model.predict(L)
# Out:
# array([-1882.05288248])

# %% [markdown]
# Input Data :

# %% [markdown]
# 1st record = 47123.3, 48553.9, 45693.6, 58180.0 :- Actual Price : 46219.5  AND  Predicted Price : 47515.32786752

# %% [markdown]
# 2nd recored = 46470.7, 47901.4, 46003.0, 60960.0 :- Actual Price: 47123.3 AND Predicted Price : 47486.52735234
